# %%
# %reset
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
#%matplotlib inline  
#%matplotlib
#matplotlib qt
#from matplotlib import pyplot as plt
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.5/site-packages/matplotlib/backends/qt_compat.py in <module>()
#     197     try:
# --> 198         from PySide import QtCore, QtGui, __version__, __version_info__
#     199     except ImportError:
#
# ImportError: No module named 'PySide'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-8080b689d058> in <module>()
#       5 #%matplotlib inline
#       6 #%matplotlib
# ----> 7 get_ipython().magic('matplotlib qt')
#       8 #from matplotlib import pyplot as plt
#       9 import matplotlib
#
# ...

# %%
#from mesh2D import mesh2DInclusion
from mesh2D import SquareWithInclusion
n = 3
mrl = 10
coords, emat = SquareWithInclusion(mrl,n,[])
#print(coords.shape())

N = n+1;
i_perim = np.concatenate(
    (np.arange(0,N-1),
    np.arange(N-1, N**2-1, N),
    np.arange(N**2-1, N**2-N, -1),
    np.arange(N**2-n-1,N-1,-N)))

#print(emat)
#print(coords)
print(np.shape(coords))
#xcoords = coords[:,0]
#ycoords = coords[:,1]


""" awefa;oweijfa;owefja;lwkefja
plt.figure(1)
plt.plot(xcoords,ycoords,'.')
plt.axis('equal')
plt.xlim(-0.5,0.5)
plt.ylim(-0.5,0.5)
for i in range(0,coords.shape[0]):
    plt.text(coords[i,0],coords[i,1],str(i))
"""

#plt.figure(1)
#np.shape(np.hstack(
#    (xcoords[emat[:,i_perim]],
#     ycoords[emat[:,i_perim]])))
    
#matplotlib.patches.Polygon(hstack(
#    xcoords[emat[:,i_perim]],
#    ycoords[emat[:,i_perim]]))
from mesh2D import plotmesh
"""
print(coords.shape)
print(emat.shape)
print(i_perim.shape)
"""
colorvec = np.concatenate(([25]*(5*mrl**2),[75]*(4*mrl**2)),axis=0)
plotmesh(coords,emat[:,i_perim],colorvec)
plt.show()
# Out:
# (8161, 2)

# %%
import numpy as np
print([4]*20)
#print(np.concatenate(([0.25]*(5*mrl**2),[0.75]*(4*mrl**2)),axis=0))
print(np.random.rand(5))
# Out:
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# [ 0.33570745  0.60152928  0.98290344  0.70873852  0.07929487]
