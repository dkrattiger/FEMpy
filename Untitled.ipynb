# %%
# %reset
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook

#import numpy as np
from matplotlib import pyplot as plt

x = np.linspace(-1,1,100)
y = np.linspace(-1,1,100)
x,y = np.meshgrid(x,y)
n1 = (x-1)*(y+1)*-1

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(x,y,n1, rstride=10, cstride=10)
plt.show()
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, PathPatch
from mpl_toolkits.mplot3d import Axes3D 
import mpl_toolkits.mplot3d.art3d as art3d


fig = plt.figure()
ax=fig.gca(projection='3d')

for i in ["x","y","z"]:
    circle = Circle((0, 0), 1)
    ax.add_patch(circle)
    art3d.pathpatch_2d_to_3d(circle, z=0, zdir=i)


ax.set_xlim3d(-2, 2)
ax.set_ylim3d(-2, 2)
ax.set_zlim3d(-2, 2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import topOpt

nelx = 120
nely = 60
volFrac = 0.5
penal = 3
rmin = 1.5


x = topOpt.topo2DSigmund(nelx,nely,volFrac,penal,rmin)

print(x)

# plot densities
plt.figure()
plt.clf()
plt.imshow(x)
plt.show()
plt.axis('equal')
# Out:
# /Users/dimitrikrattiger/anaconda3/lib/python3.6/site-packages/scipy/sparse/compressed.py:742: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   SparseEfficiencyWarning)
# It.:  1 Obj.: 372.918807672 Vol.: 0.499944441836 ch.: 0.2
# It.:  2 Obj.: 223.775479239 Vol.: 0.50000527759 ch.: 0.2
# It.:  3 Obj.: 158.765710618 Vol.: 0.500000262409 ch.: 0.2
# It.:  4 Obj.: 130.014800962 Vol.: 0.499935476709 ch.: 0.2
# It.:  5 Obj.: 117.70511633 Vol.: 0.500026427709 ch.: 0.2
# It.:  6 Obj.: 107.329916125 Vol.: 0.499940919921 ch.: 0.2
# It.:  7 Obj.: 99.7751006964 Vol.: 0.500011023113 ch.: 0.2
# It.:  8 Obj.: 94.0737826067 Vol.: 0.499989752815 ch.: 0.2
# It.:  9 Obj.: 89.8061907823 Vol.: 0.500060418432 ch.: 0.2
# It.:  10 Obj.: 86.3912458148 Vol.: 0.499902685991 ch.: 0.2
# It.:  11 Obj.: 83.9940166479 Vol.: 0.500043967784 ch.: 0.2
# It.:  12 Obj.: 82.1230877836 Vol.: 0.499949520034 ch.: 0.2
# It.:  13 Obj.: 80.6219257128 Vol.: 0.500036364012 ch.: 0.2
# It.:  14 Obj.: 79.3471439832 Vol.: 0.499919793443 ch.: 0.2
# It.:  15 Obj.: 78.3305287289 Vol.: 0.500010331253 ch.: 0.2
# It.:  16 Obj.: 77.4810227729 Vol.: 0.499937598804 ch.: 0.2
# It.:  17 Obj.: 76.7541088189 Vol.: 0.499989630841 ch.: 0.2
# It.:  18 Obj.: 76.0916401969 Vol.: 0.500037487079 ch.: 0.2
# It.:  19 Obj.: 75.5208301327 Vol.: 0.499992873131 ch.: 0.2
# It.:  20 Obj.: 75.0482786457 Vol.: 0.499975235573 ch.: 0.2
